# %%
import pandas as pd

# %%
pd.read_csv('zillow_dd.csv')
# Out:
#          Features                                        Description Data Type
# 0         tax_val  assessed tax value of a property. target variable     float
# 1            beds  number of bedrooms in a property. measured in ...     float
# 2           baths  number of bathrooms in a property. measured in...     float
# 3           sq_ft                  size of a property in square feet     float
# 4     Los Angeles  returns dummy variable that identifies propert...       int
# 5   Orange County  returns dummy variable that identifies propert...       int
# 6         Ventura  returns dummy variable that identifies propert...       int
# 7       yard_sqft                        lot size - size of property     float
# 8          county  identifies what county a property is in based ...    string
# 9            year                        year the property was built       int
# 10       lot_size  total size of the property lot, measured in sq...     float
